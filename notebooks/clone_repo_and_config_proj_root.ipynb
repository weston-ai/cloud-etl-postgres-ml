# %%
# clone_repo_and_config_proj_root.ipynb

# Colab Setup Cell: Clone + Configure Project Root via colab_setup.py

# In Colab:
# !git clone https://github.com/yourusername/cloud-etl-postgres-ml.git
# %cd /content/cloud-etl-postgres-ml

# Check out the dev branch
# !git checkout dev

# Install dotenv and run the setup script
# !pip install python-dotenv
# !python colab_setup.py
